# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # Use an ID of 0 if a word is not contained in source_vocab_to_int or target_vocab_to_int.
    source_id_text = [[source_vocab_to_int.get(w, 0) for w in s.split(' ')] for s in source_text.split('\n')]
       
    target_id_text = []
    for s in target_text.split('\n'):
        ids = [target_vocab_to_int.get(w, 0) for w in s.split(' ')]
        ids.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(ids)
    
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /Users/d065035/anaconda3/envs/tensorflow_1.1/lib/python3.6/site-packages/ipykernel/__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    input_data = tf.placeholder(tf.int32, [None, None], name="input")
    targets = tf.placeholder(tf.int32, [None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, (None,), name="target_sequence_length")
    max_target_len = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    
    return input_data, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    sliced = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    return tf.concat([go, sliced], 1)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    
    # Shape: [batch size, sequence length, embedding size]
    embedded_input = tf.contrib.layers.embed_sequence(ids=rnn_inputs,
                                                      vocab_size=source_vocab_size,
                                                      embed_dim=encoding_embedding_size)
    
    def lstm_cell(num_units):
        cell = tf.contrib.rnn.LSTMCell(num_units=num_units,
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return tf.contrib.rnn.DropoutWrapper(cell=cell, input_keep_prob=keep_prob)
    
    lstm_cells = [lstm_cell(rnn_size) for _ in range(num_layers)]
    rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=lstm_cells)
    
    output, state = tf.nn.dynamic_rnn(cell=rnn_cells,
                                      inputs=embedded_input,
                                      sequence_length=source_sequence_length,
                                      dtype=tf.float32)
    return output, state


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    
    # I don't know how to use keep_prob here. Is it required?
    
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, 
                                                        sequence_length=target_sequence_length)
    
    training_decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                       helper=training_helper,
                                                       initial_state=encoder_state,
                                                       output_layer=output_layer)
    
    training_logits, _ = tf.contrib.seq2seq.dynamic_decode(decoder=training_decoder,
                                                           impute_finished=True,
                                                           maximum_iterations=max_target_sequence_length)
    
    return training_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    
    # I don't know how to use keep_prob here. Is it required?
    
    start_token=tf.constant([start_of_sequence_id], dtype=tf.int32)
    start_tokens=tf.tile(start_token, [batch_size], name="start_tokens")
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embedding=dec_embeddings,
                                                                start_tokens=start_tokens,
                                                                end_token=end_of_sequence_id)
    
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                        helper=inference_helper,
                                                        initial_state=encoder_state,
                                                        output_layer=output_layer)
    
    inference_logits, _ = tf.contrib.seq2seq.dynamic_decode(decoder=inference_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_target_sequence_length)
    
    return inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """ 
    
    # Embed the target sequences.
    # ---------------------------
    # Shape: [vocab_size, embedding_size]
    embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    # Shape: [batch_size, sequence_length, embedding_size]
    embedding_lookup = tf.nn.embedding_lookup(params=embeddings, ids=dec_input)
        
    # Construct the decoder LSTM cells.
    # ---------------------------------
    def lstm_cell(num_units):
        cell = tf.contrib.rnn.LSTMCell(num_units=num_units,
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return tf.contrib.rnn.DropoutWrapper(cell=cell, input_keep_prob=keep_prob)
    
    lstm_cells = [lstm_cell(rnn_size) for _ in range(num_layers)]
    rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=lstm_cells)
    
    # Create an output layer.
    # -----------------------
    output_layer = Dense(units=target_vocab_size,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    # Get the training logits.
    # ------------------------
    with tf.variable_scope("decode"):
        trainig_logits = decoding_layer_train(encoder_state=encoder_state,
                                              dec_cell=rnn_cells,
                                              dec_embed_input=embedding_lookup,
                                              target_sequence_length=target_sequence_length,
                                              max_target_sequence_length=max_target_sequence_length,
                                              output_layer=output_layer,
                                              keep_prob=keep_prob)
    
    # Get the inference logits.
    # -------------------------
    with tf.variable_scope("decode", reuse=True):
        inference_logits = decoding_layer_infer(encoder_state=encoder_state,
                                                dec_cell=rnn_cells,
                                                dec_embeddings=embeddings,
                                                start_of_sequence_id=target_vocab_to_int["<GO>"],
                                                end_of_sequence_id=target_vocab_to_int["<EOS>"],
                                                max_target_sequence_length=max_target_sequence_length,
                                                vocab_size=target_vocab_size,
                                                output_layer=output_layer,
                                                batch_size=batch_size,
                                                keep_prob=keep_prob)

    
    return trainig_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network.
    :param input_data: Input placeholder.
    :param target_data: Target placeholder.
    :param keep_prob: Dropout keep probability placeholder.
    :param batch_size: Batch size.
    :param source_sequence_length: Sequence lengths of source sequences in the batch.
    :param target_sequence_length: Sequence lengths of target sequences in the batch.
    :param source_vocab_size: Source vocabulary size.
    :param target_vocab_size: Target vocabulary size.
    :param enc_embedding_size: Decoder embedding size.
    :param dec_embedding_size: Encoder embedding size.
    :param rnn_size: RNN size.
    :param num_layers: Number of layers.
    :param target_vocab_to_int: Dictionary to go from target words to IDs.
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    print("input_data: {}".format(input_data))  # Shape: [batch_size, sequence_length]
    print("target_data: {}".format(input_data))  # Shape: [batch_size, sequence_length]
    print("keep_prob: {}".format(keep_prob))
    print("batch_size: {}".format(batch_size))    
    print("source_sequence_length: {}".format(source_sequence_length))
    print("target_sequence_length: {}".format(target_sequence_length))
    print("source_vocab_size: {}".format(source_vocab_size))
    print("target_vocab_size: {}".format(target_vocab_size))
    print("enc_embedding_size: {}".format(enc_embedding_size)) 
    print("dec_embedding_size: {}".format(dec_embedding_size)) 
    print("rnn_size: {}".format(rnn_size))
    print("num_layers: {}".format(num_layers))

    # Apply embedding to the input data for the encoder.
    # The encoding_layer() function states that we should use tf.contrib.layers.embed_sequence
    # to embed the encoder input. The corresponding test also expects that rnn_inputs has shape
    # [batch_size, sequence_length]. That's why I omit the embedding here.
    
    # Encode the input.
    encoder_output, encoder_state = encoding_layer(rnn_inputs=input_data,
                                                   rnn_size=rnn_size,
                                                   num_layers=num_layers,
                                                   keep_prob=keep_prob,
                                                   source_sequence_length=source_sequence_length,
                                                   source_vocab_size=source_vocab_size,
                                                   encoding_embedding_size=enc_embedding_size)
    
    # Process the target data.    
    decoder_input = process_decoder_input(target_data=target_data,
                                          target_vocab_to_int=target_vocab_to_int,
                                          batch_size=batch_size)
    
    # Apply embedding to the target data for the decoder.
    # The decoding_layer() function states that we should embed the target sequences. Also,
    # decoding_layer_train() and decoding_layer_infer() used there expect the embedded sequences
    # and the embeddings as input. That's why I omit the embedding here.
    
    # Decode the encoded input.                    
    training_logits, inference_logits = decoding_layer(dec_input=decoder_input,
                                                       encoder_state=encoder_state,
                                                       target_sequence_length=target_sequence_length,
                                                       max_target_sequence_length=max_target_sentence_length,
                                                       rnn_size=rnn_size,
                                                       num_layers=num_layers,
                                                       target_vocab_to_int=target_vocab_to_int,
                                                       target_vocab_size=target_vocab_size,
                                                       batch_size=batch_size,
                                                       keep_prob=keep_prob,
                                                       decoding_embedding_size=dec_embedding_size)    
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# input_data: Tensor("Placeholder_6:0", shape=(64, 22), dtype=int32)
# target_data: Tensor("Placeholder_6:0", shape=(64, 22), dtype=int32)
# keep_prob: Tensor("Placeholder_8:0", dtype=float32)
# batch_size: 64
# source_sequence_length: Tensor("source_sequence_length:0", shape=(?,), dtype=int32)
# target_sequence_length: Tensor("target_sequence_length:0", shape=(?,), dtype=int32)
# source_vocab_size: 300
# target_vocab_size: 300
# enc_embedding_size: 100
# dec_embedding_size: 100
# rnn_size: 512
# num_layers: 3
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of epochs.
epochs = 20

# Batch size.
batch_size = 128

# RNN size, i.e. the number of hidden units in the LSTM cells.
rnn_size = 64

# Number of LSTM layers.
num_layers = 2

# Embedding sizes.
# I read somewhere that the embedding size should be bigger than the RNN size.
# I'm using double the number of hidden units in the LSTMs.
encoding_embedding_size = 128
decoding_embedding_size = 128

# Learning rate.
learning_rate = 0.001

# Dropout keep probability.
keep_probability = 0.6

# How many steps between each debug statement?
display_step = 51

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# input_data: Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# target_data: Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# keep_prob: Tensor("keep_prob:0", dtype=float32)
# batch_size: 128
# source_sequence_length: Tensor("source_sequence_length:0", shape=(?,), dtype=int32)
# target_sequence_length: Tensor("target_sequence_length:0", shape=(?,), dtype=int32)
# source_vocab_size: 231
# target_vocab_size: 358
# enc_embedding_size: 128
# dec_embedding_size: 128
# rnn_size: 64
# num_layers: 2

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
# I'm addinga few things to plot the loss and test/validation accuracies.
# See the START and END delimiters.

# ----- START ----- #
# %matplotlib inline

import matplotlib.pyplot as plt

batches = []
losses = []
train_accs = []
valid_accs = []
# ----- END ----- #

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:

                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                # ----- START ----- #
                previous_batch = batches[-1] if batches else 0
                batches.append(display_step + previous_batch)
                losses.append(loss)
                train_accs.append(train_acc)
                valid_accs.append(valid_acc)
                # ----- END ----- #

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)

    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   51/1077 - Train Accuracy: 0.2941, Validation Accuracy: 0.3356, Loss: 3.4431
# Epoch   0 Batch  102/1077 - Train Accuracy: 0.3285, Validation Accuracy: 0.3679, Loss: 3.0425
# Epoch   0 Batch  153/1077 - Train Accuracy: 0.3316, Validation Accuracy: 0.3970, Loss: 2.9317
# Epoch   0 Batch  204/1077 - Train Accuracy: 0.3676, Validation Accuracy: 0.4233, Loss: 2.6717
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.3738, Validation Accuracy: 0.4290, Loss: 2.5076
# Epoch   0 Batch  306/1077 - Train Accuracy: 0.3973, Validation Accuracy: 0.4357, Loss: 2.2550
# Epoch   0 Batch  357/1077 - Train Accuracy: 0.4639, Validation Accuracy: 0.4815, Loss: 2.0331
# Epoch   0 Batch  408/1077 - Train Accuracy: 0.4309, Validation Accuracy: 0.4893, Loss: 2.0286
# Epoch   0 Batch  459/1077 - Train Accuracy: 0.4728, Validation Accuracy: 0.5025, Loss: 1.7605
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.4968, Loss: 1.6237
# Epoch   0 Batch  561/1077 - Train Accuracy: 0.4944, Validation Accuracy: 0.5170, Loss: 1.4064
# Epoch   0 Batch  612/1077 - Train Accuracy: 0.5097, Validation Accuracy: 0.5036, Loss: 1.2565
# Epoch   0 Batch  663/1077 - Train Accuracy: 0.4531, Validation Accuracy: 0.5000, Loss: 1.2264
# Epoch   0 Batch  714/1077 - Train Accuracy: 0.4360, Validation Accuracy: 0.4961, Loss: 1.1768
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.4910, Validation Accuracy: 0.5103, Loss: 1.0578
# Epoch   0 Batch  816/1077 - Train Accuracy: 0.4905, Validation Accuracy: 0.5224, Loss: 1.0838
# Epoch   0 Batch  867/1077 - Train Accuracy: 0.4734, Validation Accuracy: 0.5252, Loss: 1.0616
# Epoch   0 Batch  918/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5195, Loss: 0.9098
# Epoch   0 Batch  969/1077 - Train Accuracy: 0.5279, Validation Accuracy: 0.5323, Loss: 0.9148
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.5148, Validation Accuracy: 0.5288, Loss: 0.8904
# Epoch   0 Batch 1071/1077 - Train Accuracy: 0.5008, Validation Accuracy: 0.5415, Loss: 0.8973
# Epoch   1 Batch   51/1077 - Train Accuracy: 0.4992, Validation Accuracy: 0.5483, Loss: 0.8246
# Epoch   1 Batch  102/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5515, Loss: 0.8249
# Epoch   1 Batch  153/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5483, Loss: 0.8507
# Epoch   1 Batch  204/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5639, Loss: 0.8109
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5540, Loss: 0.7984
# Epoch   1 Batch  306/1077 - Train Accuracy: 0.5644, Validation Accuracy: 0.5760, Loss: 0.7423
# Epoch   1 Batch  357/1077 - Train Accuracy: 0.5975, Validation Accuracy: 0.5831, Loss: 0.7106
# Epoch   1 Batch  408/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5948, Loss: 0.7384
# Epoch   1 Batch  459/1077 - Train Accuracy: 0.6075, Validation Accuracy: 0.5895, Loss: 0.6918
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.6074, Validation Accuracy: 0.6005, Loss: 0.6921
# Epoch   1 Batch  561/1077 - Train Accuracy: 0.6157, Validation Accuracy: 0.6072, Loss: 0.6726
# Epoch   1 Batch  612/1077 - Train Accuracy: 0.6276, Validation Accuracy: 0.6009, Loss: 0.6438
# Epoch   1 Batch  663/1077 - Train Accuracy: 0.5836, Validation Accuracy: 0.6211, Loss: 0.6447
# Epoch   1 Batch  714/1077 - Train Accuracy: 0.5919, Validation Accuracy: 0.6172, Loss: 0.6616
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.6219, Validation Accuracy: 0.6254, Loss: 0.6243
# Epoch   1 Batch  816/1077 - Train Accuracy: 0.6587, Validation Accuracy: 0.6335, Loss: 0.6547
# Epoch   1 Batch  867/1077 - Train Accuracy: 0.5641, Validation Accuracy: 0.6239, Loss: 0.6643
# Epoch   1 Batch  918/1077 - Train Accuracy: 0.6659, Validation Accuracy: 0.6264, Loss: 0.5713
# Epoch   1 Batch  969/1077 - Train Accuracy: 0.6473, Validation Accuracy: 0.6275, Loss: 0.5891
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.6441, Validation Accuracy: 0.6399, Loss: 0.5646
# Epoch   1 Batch 1071/1077 - Train Accuracy: 0.6281, Validation Accuracy: 0.6449, Loss: 0.5640
# Epoch   2 Batch   51/1077 - Train Accuracy: 0.6652, Validation Accuracy: 0.6449, Loss: 0.5483
# Epoch   2 Batch  102/1077 - Train Accuracy: 0.6711, Validation Accuracy: 0.6452, Loss: 0.5346
# Epoch   2 Batch  153/1077 - Train Accuracy: 0.6617, Validation Accuracy: 0.6456, Loss: 0.5692
# Epoch   2 Batch  204/1077 - Train Accuracy: 0.6648, Validation Accuracy: 0.6587, Loss: 0.5516
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.6527, Validation Accuracy: 0.6584, Loss: 0.5279
# Epoch   2 Batch  306/1077 - Train Accuracy: 0.6596, Validation Accuracy: 0.6673, Loss: 0.4994
# Epoch   2 Batch  357/1077 - Train Accuracy: 0.6652, Validation Accuracy: 0.6637, Loss: 0.4880
# Epoch   2 Batch  408/1077 - Train Accuracy: 0.6445, Validation Accuracy: 0.6705, Loss: 0.4923
# Epoch   2 Batch  459/1077 - Train Accuracy: 0.6834, Validation Accuracy: 0.6776, Loss: 0.4643
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.6727, Validation Accuracy: 0.6857, Loss: 0.4815
# Epoch   2 Batch  561/1077 - Train Accuracy: 0.7236, Validation Accuracy: 0.6747, Loss: 0.4473
# Epoch   2 Batch  612/1077 - Train Accuracy: 0.7009, Validation Accuracy: 0.6861, Loss: 0.4371
# Epoch   2 Batch  663/1077 - Train Accuracy: 0.6707, Validation Accuracy: 0.6921, Loss: 0.4278
# Epoch   2 Batch  714/1077 - Train Accuracy: 0.6786, Validation Accuracy: 0.6733, Loss: 0.4578
# Epoch   2 Batch  765/1077 - Train Accuracy: 0.7141, Validation Accuracy: 0.6967, Loss: 0.4225
# Epoch   2 Batch  816/1077 - Train Accuracy: 0.7586, Validation Accuracy: 0.7028, Loss: 0.4633
# Epoch   2 Batch  867/1077 - Train Accuracy: 0.6820, Validation Accuracy: 0.6879, Loss: 0.4565
# Epoch   2 Batch  918/1077 - Train Accuracy: 0.7221, Validation Accuracy: 0.7067, Loss: 0.3998
# Epoch   2 Batch  969/1077 - Train Accuracy: 0.7284, Validation Accuracy: 0.6989, Loss: 0.4207
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.7008, Validation Accuracy: 0.6918, Loss: 0.3900
# Epoch   2 Batch 1071/1077 - Train Accuracy: 0.7367, Validation Accuracy: 0.7053, Loss: 0.3849
# Epoch   3 Batch   51/1077 - Train Accuracy: 0.7129, Validation Accuracy: 0.7042, Loss: 0.3874
# Epoch   3 Batch  102/1077 - Train Accuracy: 0.7582, Validation Accuracy: 0.7077, Loss: 0.3734
# Epoch   3 Batch  153/1077 - Train Accuracy: 0.7332, Validation Accuracy: 0.7195, Loss: 0.4214
# Epoch   3 Batch  204/1077 - Train Accuracy: 0.7145, Validation Accuracy: 0.7212, Loss: 0.4045
# Epoch   3 Batch  255/1077 - Train Accuracy: 0.7094, Validation Accuracy: 0.6964, Loss: 0.3677
# Epoch   3 Batch  306/1077 - Train Accuracy: 0.7173, Validation Accuracy: 0.7127, Loss: 0.3622
# Epoch   3 Batch  357/1077 - Train Accuracy: 0.7321, Validation Accuracy: 0.7234, Loss: 0.3483
# Epoch   3 Batch  408/1077 - Train Accuracy: 0.7355, Validation Accuracy: 0.7191, Loss: 0.3575
# Epoch   3 Batch  459/1077 - Train Accuracy: 0.7589, Validation Accuracy: 0.7319, Loss: 0.3296
# Epoch   3 Batch  510/1077 - Train Accuracy: 0.7523, Validation Accuracy: 0.7266, Loss: 0.3373
# Epoch   3 Batch  561/1077 - Train Accuracy: 0.7742, Validation Accuracy: 0.7244, Loss: 0.3235
# Epoch   3 Batch  612/1077 - Train Accuracy: 0.7839, Validation Accuracy: 0.7344, Loss: 0.3141
# Epoch   3 Batch  663/1077 - Train Accuracy: 0.7641, Validation Accuracy: 0.7280, Loss: 0.3046
# Epoch   3 Batch  714/1077 - Train Accuracy: 0.7716, Validation Accuracy: 0.7475, Loss: 0.3207
# Epoch   3 Batch  765/1077 - Train Accuracy: 0.7676, Validation Accuracy: 0.7369, Loss: 0.2993
# Epoch   3 Batch  816/1077 - Train Accuracy: 0.8183, Validation Accuracy: 0.7656, Loss: 0.3232
# Epoch   3 Batch  867/1077 - Train Accuracy: 0.7598, Validation Accuracy: 0.7692, Loss: 0.3425
# Epoch   3 Batch  918/1077 - Train Accuracy: 0.7738, Validation Accuracy: 0.7447, Loss: 0.2896
# Epoch   3 Batch  969/1077 - Train Accuracy: 0.7753, Validation Accuracy: 0.7440, Loss: 0.3152
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.7680, Validation Accuracy: 0.7575, Loss: 0.2778
# Epoch   3 Batch 1071/1077 - Train Accuracy: 0.8012, Validation Accuracy: 0.7724, Loss: 0.2844
# Epoch   4 Batch   51/1077 - Train Accuracy: 0.7836, Validation Accuracy: 0.7688, Loss: 0.2787
# Epoch   4 Batch  102/1077 - Train Accuracy: 0.8078, Validation Accuracy: 0.7646, Loss: 0.2652
# Epoch   4 Batch  153/1077 - Train Accuracy: 0.7883, Validation Accuracy: 0.7710, Loss: 0.3106
# Epoch   4 Batch  204/1077 - Train Accuracy: 0.7750, Validation Accuracy: 0.7759, Loss: 0.2924
# Epoch   4 Batch  255/1077 - Train Accuracy: 0.7848, Validation Accuracy: 0.7749, Loss: 0.2794
# Epoch   4 Batch  306/1077 - Train Accuracy: 0.7961, Validation Accuracy: 0.7901, Loss: 0.2653
# Epoch   4 Batch  357/1077 - Train Accuracy: 0.7943, Validation Accuracy: 0.7866, Loss: 0.2469
# Epoch   4 Batch  408/1077 - Train Accuracy: 0.7824, Validation Accuracy: 0.7837, Loss: 0.2543
# Epoch   4 Batch  459/1077 - Train Accuracy: 0.7987, Validation Accuracy: 0.7599, Loss: 0.2354
# Epoch   4 Batch  510/1077 - Train Accuracy: 0.7855, Validation Accuracy: 0.7834, Loss: 0.2470
# Epoch   4 Batch  561/1077 - Train Accuracy: 0.8051, Validation Accuracy: 0.7812, Loss: 0.2404
# Epoch   4 Batch  612/1077 - Train Accuracy: 0.8337, Validation Accuracy: 0.8018, Loss: 0.2347
# Epoch   4 Batch  663/1077 - Train Accuracy: 0.8152, Validation Accuracy: 0.7812, Loss: 0.2274
# Epoch   4 Batch  714/1077 - Train Accuracy: 0.8047, Validation Accuracy: 0.8111, Loss: 0.2377
# Epoch   4 Batch  765/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.7987, Loss: 0.2241
# Epoch   4 Batch  816/1077 - Train Accuracy: 0.8606, Validation Accuracy: 0.7958, Loss: 0.2493
# Epoch   4 Batch  867/1077 - Train Accuracy: 0.7980, Validation Accuracy: 0.8075, Loss: 0.2661
# Epoch   4 Batch  918/1077 - Train Accuracy: 0.8278, Validation Accuracy: 0.8200, Loss: 0.2199
# Epoch   4 Batch  969/1077 - Train Accuracy: 0.8211, Validation Accuracy: 0.8029, Loss: 0.2338
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.8145, Validation Accuracy: 0.8178, Loss: 0.2089
# Epoch   4 Batch 1071/1077 - Train Accuracy: 0.8477, Validation Accuracy: 0.8253, Loss: 0.2059
# Epoch   5 Batch   51/1077 - Train Accuracy: 0.8293, Validation Accuracy: 0.8196, Loss: 0.2098
# Epoch   5 Batch  102/1077 - Train Accuracy: 0.8375, Validation Accuracy: 0.8107, Loss: 0.1959
# Epoch   5 Batch  153/1077 - Train Accuracy: 0.8152, Validation Accuracy: 0.8324, Loss: 0.2353
# Epoch   5 Batch  204/1077 - Train Accuracy: 0.8125, Validation Accuracy: 0.8377, Loss: 0.2194
# Epoch   5 Batch  255/1077 - Train Accuracy: 0.8301, Validation Accuracy: 0.8072, Loss: 0.1992
# Epoch   5 Batch  306/1077 - Train Accuracy: 0.8657, Validation Accuracy: 0.8430, Loss: 0.2046
# Epoch   5 Batch  357/1077 - Train Accuracy: 0.8144, Validation Accuracy: 0.8320, Loss: 0.1896
# Epoch   5 Batch  408/1077 - Train Accuracy: 0.8605, Validation Accuracy: 0.8349, Loss: 0.1982
# Epoch   5 Batch  459/1077 - Train Accuracy: 0.8624, Validation Accuracy: 0.8299, Loss: 0.1735
# Epoch   5 Batch  510/1077 - Train Accuracy: 0.8383, Validation Accuracy: 0.8413, Loss: 0.1938
# Epoch   5 Batch  561/1077 - Train Accuracy: 0.8400, Validation Accuracy: 0.8452, Loss: 0.1820
# Epoch   5 Batch  612/1077 - Train Accuracy: 0.8657, Validation Accuracy: 0.8335, Loss: 0.1758
# Epoch   5 Batch  663/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.8303, Loss: 0.1707
# Epoch   5 Batch  714/1077 - Train Accuracy: 0.8460, Validation Accuracy: 0.8416, Loss: 0.1767
# Epoch   5 Batch  765/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8441, Loss: 0.1639
# Epoch   5 Batch  816/1077 - Train Accuracy: 0.9034, Validation Accuracy: 0.8548, Loss: 0.1844
# Epoch   5 Batch  867/1077 - Train Accuracy: 0.8484, Validation Accuracy: 0.8324, Loss: 0.2169
# Epoch   5 Batch  918/1077 - Train Accuracy: 0.8586, Validation Accuracy: 0.8438, Loss: 0.1675
# Epoch   5 Batch  969/1077 - Train Accuracy: 0.8501, Validation Accuracy: 0.8402, Loss: 0.1776
# Epoch   5 Batch 1020/1077 - Train Accuracy: 0.8398, Validation Accuracy: 0.8473, Loss: 0.1662
# Epoch   5 Batch 1071/1077 - Train Accuracy: 0.8863, Validation Accuracy: 0.8427, Loss: 0.1515
# Epoch   6 Batch   51/1077 - Train Accuracy: 0.8695, Validation Accuracy: 0.8406, Loss: 0.1612
# Epoch   6 Batch  102/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8484, Loss: 0.1519
# Epoch   6 Batch  153/1077 - Train Accuracy: 0.8430, Validation Accuracy: 0.8327, Loss: 0.1825
# Epoch   6 Batch  204/1077 - Train Accuracy: 0.8496, Validation Accuracy: 0.8558, Loss: 0.1728
# Epoch   6 Batch  255/1077 - Train Accuracy: 0.8863, Validation Accuracy: 0.8555, Loss: 0.1518
# Epoch   6 Batch  306/1077 - Train Accuracy: 0.8903, Validation Accuracy: 0.8406, Loss: 0.1604
# Epoch   6 Batch  357/1077 - Train Accuracy: 0.8460, Validation Accuracy: 0.8540, Loss: 0.1537
# Epoch   6 Batch  408/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8285, Loss: 0.1528
# Epoch   6 Batch  459/1077 - Train Accuracy: 0.8858, Validation Accuracy: 0.8398, Loss: 0.1364
# Epoch   6 Batch  510/1077 - Train Accuracy: 0.8574, Validation Accuracy: 0.8544, Loss: 0.1424
# Epoch   6 Batch  561/1077 - Train Accuracy: 0.8802, Validation Accuracy: 0.8675, Loss: 0.1437
# Epoch   6 Batch  612/1077 - Train Accuracy: 0.8958, Validation Accuracy: 0.8530, Loss: 0.1309
# Epoch   6 Batch  663/1077 - Train Accuracy: 0.8836, Validation Accuracy: 0.8658, Loss: 0.1288
# Epoch   6 Batch  714/1077 - Train Accuracy: 0.8769, Validation Accuracy: 0.8651, Loss: 0.1279
# Epoch   6 Batch  765/1077 - Train Accuracy: 0.8773, Validation Accuracy: 0.8548, Loss: 0.1381
# Epoch   6 Batch  816/1077 - Train Accuracy: 0.9186, Validation Accuracy: 0.8675, Loss: 0.1417
# Epoch   6 Batch  867/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.8569, Loss: 0.1669
# Epoch   6 Batch  918/1077 - Train Accuracy: 0.8810, Validation Accuracy: 0.8619, Loss: 0.1240
# Epoch   6 Batch  969/1077 - Train Accuracy: 0.8549, Validation Accuracy: 0.8523, Loss: 0.1503
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.8612, Loss: 0.1238
# Epoch   6 Batch 1071/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.8750, Loss: 0.1188
# Epoch   7 Batch   51/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8587, Loss: 0.1262
# Epoch   7 Batch  102/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.8636, Loss: 0.1149
# Epoch   7 Batch  153/1077 - Train Accuracy: 0.8742, Validation Accuracy: 0.8565, Loss: 0.1419
# Epoch   7 Batch  204/1077 - Train Accuracy: 0.8703, Validation Accuracy: 0.8562, Loss: 0.1402
# Epoch   7 Batch  255/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8683, Loss: 0.1221
# Epoch   7 Batch  306/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8562, Loss: 0.1255
# Epoch   7 Batch  357/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8509, Loss: 0.1154
# Epoch   7 Batch  408/1077 - Train Accuracy: 0.8918, Validation Accuracy: 0.8594, Loss: 0.1246
# Epoch   7 Batch  459/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.8736, Loss: 0.1151
# Epoch   7 Batch  510/1077 - Train Accuracy: 0.8762, Validation Accuracy: 0.8544, Loss: 0.1139
# Epoch   7 Batch  561/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8473, Loss: 0.1145
# Epoch   7 Batch  612/1077 - Train Accuracy: 0.9275, Validation Accuracy: 0.8704, Loss: 0.1005
# Epoch   7 Batch  663/1077 - Train Accuracy: 0.8930, Validation Accuracy: 0.8587, Loss: 0.0962
# Epoch   7 Batch  714/1077 - Train Accuracy: 0.8958, Validation Accuracy: 0.8601, Loss: 0.1124
# Epoch   7 Batch  765/1077 - Train Accuracy: 0.8969, Validation Accuracy: 0.8683, Loss: 0.1068
# Epoch   7 Batch  816/1077 - Train Accuracy: 0.9042, Validation Accuracy: 0.8722, Loss: 0.1173
# Epoch   7 Batch  867/1077 - Train Accuracy: 0.8719, Validation Accuracy: 0.8615, Loss: 0.1474
# Epoch   7 Batch  918/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8544, Loss: 0.1044
# Epoch   7 Batch  969/1077 - Train Accuracy: 0.8776, Validation Accuracy: 0.8750, Loss: 0.1179
# Epoch   7 Batch 1020/1077 - Train Accuracy: 0.9012, Validation Accuracy: 0.8711, Loss: 0.1001
# Epoch   7 Batch 1071/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8704, Loss: 0.0975
# Epoch   8 Batch   51/1077 - Train Accuracy: 0.8863, Validation Accuracy: 0.8828, Loss: 0.0991
# Epoch   8 Batch  102/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8764, Loss: 0.0987
# Epoch   8 Batch  153/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8803, Loss: 0.1232
# Epoch   8 Batch  204/1077 - Train Accuracy: 0.8637, Validation Accuracy: 0.8757, Loss: 0.1262
# Epoch   8 Batch  255/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8711, Loss: 0.0952
# Epoch   8 Batch  306/1077 - Train Accuracy: 0.9144, Validation Accuracy: 0.8633, Loss: 0.1084
# Epoch   8 Batch  357/1077 - Train Accuracy: 0.8802, Validation Accuracy: 0.8597, Loss: 0.0942
# Epoch   8 Batch  408/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8746, Loss: 0.1053
# Epoch   8 Batch  459/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.8768, Loss: 0.0891
# Epoch   8 Batch  510/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8732, Loss: 0.1026
# Epoch   8 Batch  561/1077 - Train Accuracy: 0.9040, Validation Accuracy: 0.8700, Loss: 0.0955
# Epoch   8 Batch  612/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.8686, Loss: 0.0806
# Epoch   8 Batch  663/1077 - Train Accuracy: 0.8973, Validation Accuracy: 0.8651, Loss: 0.0905
# Epoch   8 Batch  714/1077 - Train Accuracy: 0.9100, Validation Accuracy: 0.8661, Loss: 0.0858
# Epoch   8 Batch  765/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.8899, Loss: 0.0984
# Epoch   8 Batch  816/1077 - Train Accuracy: 0.9264, Validation Accuracy: 0.8857, Loss: 0.0899
# Epoch   8 Batch  867/1077 - Train Accuracy: 0.8758, Validation Accuracy: 0.8771, Loss: 0.1352
# Epoch   8 Batch  918/1077 - Train Accuracy: 0.9208, Validation Accuracy: 0.8793, Loss: 0.0806
# Epoch   8 Batch  969/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8849, Loss: 0.1031
# Epoch   8 Batch 1020/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.8778, Loss: 0.0875
# Epoch   8 Batch 1071/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.8796, Loss: 0.0789
# Epoch   9 Batch   51/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.8835, Loss: 0.0806
# Epoch   9 Batch  102/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8768, Loss: 0.0805
# Epoch   9 Batch  153/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.8821, Loss: 0.0945
# Epoch   9 Batch  204/1077 - Train Accuracy: 0.8805, Validation Accuracy: 0.8711, Loss: 0.1037
# Epoch   9 Batch  255/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.8963, Loss: 0.0845
# Epoch   9 Batch  306/1077 - Train Accuracy: 0.9048, Validation Accuracy: 0.8761, Loss: 0.0879
# Epoch   9 Batch  357/1077 - Train Accuracy: 0.8958, Validation Accuracy: 0.8888, Loss: 0.0884
# Epoch   9 Batch  408/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8860, Loss: 0.0925
# Epoch   9 Batch  459/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.8846, Loss: 0.0798
# Epoch   9 Batch  510/1077 - Train Accuracy: 0.8875, Validation Accuracy: 0.8956, Loss: 0.0822
# Epoch   9 Batch  561/1077 - Train Accuracy: 0.9048, Validation Accuracy: 0.8860, Loss: 0.0755
# Epoch   9 Batch  612/1077 - Train Accuracy: 0.9397, Validation Accuracy: 0.8807, Loss: 0.0696
# Epoch   9 Batch  663/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8924, Loss: 0.0750
# Epoch   9 Batch  714/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8810, Loss: 0.0773
# Epoch   9 Batch  765/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8800, Loss: 0.0824
# Epoch   9 Batch  816/1077 - Train Accuracy: 0.9404, Validation Accuracy: 0.8988, Loss: 0.0777
# Epoch   9 Batch  867/1077 - Train Accuracy: 0.8816, Validation Accuracy: 0.8920, Loss: 0.1117
# Epoch   9 Batch  918/1077 - Train Accuracy: 0.9144, Validation Accuracy: 0.8771, Loss: 0.0823
# Epoch   9 Batch  969/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8867, Loss: 0.0929
# Epoch   9 Batch 1020/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.8960, Loss: 0.0728
# Epoch   9 Batch 1071/1077 - Train Accuracy: 0.9098, Validation Accuracy: 0.8867, Loss: 0.0672
# Epoch  10 Batch   51/1077 - Train Accuracy: 0.8961, Validation Accuracy: 0.8949, Loss: 0.0707
# Epoch  10 Batch  102/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9137, Loss: 0.0733
# Epoch  10 Batch  153/1077 - Train Accuracy: 0.9090, Validation Accuracy: 0.8938, Loss: 0.0802
# Epoch  10 Batch  204/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.9006, Loss: 0.0965
# Epoch  10 Batch  255/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9077, Loss: 0.0727
# Epoch  10 Batch  306/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.8864, Loss: 0.0843
# Epoch  10 Batch  357/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.9006, Loss: 0.0725
# Epoch  10 Batch  408/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8899, Loss: 0.0761
# Epoch  10 Batch  459/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.8878, Loss: 0.0711
# Epoch  10 Batch  510/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8871, Loss: 0.0767
# Epoch  10 Batch  561/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.8967, Loss: 0.0694
# Epoch  10 Batch  612/1077 - Train Accuracy: 0.9356, Validation Accuracy: 0.8952, Loss: 0.0581
# Epoch  10 Batch  663/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.8857, Loss: 0.0645
# Epoch  10 Batch  714/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.8949, Loss: 0.0617
# Epoch  10 Batch  765/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.9055, Loss: 0.0754
# Epoch  10 Batch  816/1077 - Train Accuracy: 0.9470, Validation Accuracy: 0.8981, Loss: 0.0698
# Epoch  10 Batch  867/1077 - Train Accuracy: 0.8957, Validation Accuracy: 0.9020, Loss: 0.1101
# Epoch  10 Batch  918/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9052, Loss: 0.0640
# Epoch  10 Batch  969/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.8874, Loss: 0.0806
# Epoch  10 Batch 1020/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9027, Loss: 0.0593
# Epoch  10 Batch 1071/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9062, Loss: 0.0575
# Epoch  11 Batch   51/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.9031, Loss: 0.0637
# Epoch  11 Batch  102/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.8995, Loss: 0.0605
# Epoch  11 Batch  153/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.8888, Loss: 0.0779
# Epoch  11 Batch  204/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8949, Loss: 0.0838
# Epoch  11 Batch  255/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9002, Loss: 0.0651
# Epoch  11 Batch  306/1077 - Train Accuracy: 0.9193, Validation Accuracy: 0.8888, Loss: 0.0753
# Epoch  11 Batch  357/1077 - Train Accuracy: 0.8962, Validation Accuracy: 0.9116, Loss: 0.0609
# Epoch  11 Batch  408/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.8874, Loss: 0.0707
# Epoch  11 Batch  459/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.8945, Loss: 0.0616
# Epoch  11 Batch  510/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.9070, Loss: 0.0638
# Epoch  11 Batch  561/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9134, Loss: 0.0601
# Epoch  11 Batch  612/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.8984, Loss: 0.0607
# Epoch  11 Batch  663/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9070, Loss: 0.0562
# Epoch  11 Batch  714/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9045, Loss: 0.0620
# Epoch  11 Batch  765/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9119, Loss: 0.0658
# Epoch  11 Batch  816/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.9148, Loss: 0.0637
# Epoch  11 Batch  867/1077 - Train Accuracy: 0.8930, Validation Accuracy: 0.9237, Loss: 0.1030
# Epoch  11 Batch  918/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.9020, Loss: 0.0570
# Epoch  11 Batch  969/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.9062, Loss: 0.0721
# Epoch  11 Batch 1020/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9052, Loss: 0.0559
# Epoch  11 Batch 1071/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.9173, Loss: 0.0534
# Epoch  12 Batch   51/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.9347, Loss: 0.0581
# Epoch  12 Batch  102/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9112, Loss: 0.0598
# Epoch  12 Batch  153/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8881, Loss: 0.0678
# Epoch  12 Batch  204/1077 - Train Accuracy: 0.8930, Validation Accuracy: 0.9151, Loss: 0.0747
# Epoch  12 Batch  255/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9162, Loss: 0.0548
# Epoch  12 Batch  306/1077 - Train Accuracy: 0.9196, Validation Accuracy: 0.9052, Loss: 0.0718
# Epoch  12 Batch  357/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.9261, Loss: 0.0585
# Epoch  12 Batch  408/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.9180, Loss: 0.0668
# Epoch  12 Batch  459/1077 - Train Accuracy: 0.9364, Validation Accuracy: 0.9165, Loss: 0.0630
# Epoch  12 Batch  510/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.9247, Loss: 0.0661
# Epoch  12 Batch  561/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9229, Loss: 0.0519
# Epoch  12 Batch  612/1077 - Train Accuracy: 0.9423, Validation Accuracy: 0.9102, Loss: 0.0516
# Epoch  12 Batch  663/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9041, Loss: 0.0518
# Epoch  12 Batch  714/1077 - Train Accuracy: 0.9420, Validation Accuracy: 0.9190, Loss: 0.0580
# Epoch  12 Batch  765/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9144, Loss: 0.0620
# Epoch  12 Batch  816/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9237, Loss: 0.0572
# Epoch  12 Batch  867/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.9212, Loss: 0.0938
# Epoch  12 Batch  918/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.9205, Loss: 0.0533
# Epoch  12 Batch  969/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9268, Loss: 0.0664
# Epoch  12 Batch 1020/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9215, Loss: 0.0487
# Epoch  12 Batch 1071/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9176, Loss: 0.0475
# Epoch  13 Batch   51/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9162, Loss: 0.0501
# Epoch  13 Batch  102/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9151, Loss: 0.0472
# Epoch  13 Batch  153/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9116, Loss: 0.0651
# Epoch  13 Batch  204/1077 - Train Accuracy: 0.9008, Validation Accuracy: 0.9165, Loss: 0.0737
# Epoch  13 Batch  255/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9315, Loss: 0.0528
# Epoch  13 Batch  306/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.9219, Loss: 0.0607
# Epoch  13 Batch  357/1077 - Train Accuracy: 0.9200, Validation Accuracy: 0.9141, Loss: 0.0520
# Epoch  13 Batch  408/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9077, Loss: 0.0554
# Epoch  13 Batch  459/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.9272, Loss: 0.0521
# Epoch  13 Batch  510/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9325, Loss: 0.0576
# Epoch  13 Batch  561/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9396, Loss: 0.0508
# Epoch  13 Batch  612/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9222, Loss: 0.0503
# Epoch  13 Batch  663/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9158, Loss: 0.0481
# Epoch  13 Batch  714/1077 - Train Accuracy: 0.9442, Validation Accuracy: 0.9229, Loss: 0.0476
# Epoch  13 Batch  765/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9187, Loss: 0.0626
# Epoch  13 Batch  816/1077 - Train Accuracy: 0.9593, Validation Accuracy: 0.9222, Loss: 0.0504
# Epoch  13 Batch  867/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.9283, Loss: 0.0881
# Epoch  13 Batch  918/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9247, Loss: 0.0523
# Epoch  13 Batch  969/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.9265, Loss: 0.0622
# Epoch  13 Batch 1020/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9244, Loss: 0.0478
# Epoch  13 Batch 1071/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9222, Loss: 0.0458
# Epoch  14 Batch   51/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9371, Loss: 0.0515
# Epoch  14 Batch  102/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9109, Loss: 0.0435
# Epoch  14 Batch  153/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9126, Loss: 0.0584
# Epoch  14 Batch  204/1077 - Train Accuracy: 0.8883, Validation Accuracy: 0.9134, Loss: 0.0687
# Epoch  14 Batch  255/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9315, Loss: 0.0446
# Epoch  14 Batch  306/1077 - Train Accuracy: 0.9241, Validation Accuracy: 0.9286, Loss: 0.0679
# Epoch  14 Batch  357/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9332, Loss: 0.0519
# Epoch  14 Batch  408/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9293, Loss: 0.0547
# Epoch  14 Batch  459/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9187, Loss: 0.0507
# Epoch  14 Batch  510/1077 - Train Accuracy: 0.9164, Validation Accuracy: 0.9165, Loss: 0.0514
# Epoch  14 Batch  561/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9286, Loss: 0.0456
# Epoch  14 Batch  612/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9393, Loss: 0.0488
# Epoch  14 Batch  663/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9347, Loss: 0.0423
# Epoch  14 Batch  714/1077 - Train Accuracy: 0.9557, Validation Accuracy: 0.9308, Loss: 0.0475
# Epoch  14 Batch  765/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9450, Loss: 0.0494
# Epoch  14 Batch  816/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9315, Loss: 0.0496
# Epoch  14 Batch  867/1077 - Train Accuracy: 0.9004, Validation Accuracy: 0.9222, Loss: 0.0982
# Epoch  14 Batch  918/1077 - Train Accuracy: 0.9360, Validation Accuracy: 0.9308, Loss: 0.0460
# Epoch  14 Batch  969/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9332, Loss: 0.0530
# Epoch  14 Batch 1020/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9347, Loss: 0.0407
# Epoch  14 Batch 1071/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9297, Loss: 0.0374
# Epoch  15 Batch   51/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9375, Loss: 0.0465
# Epoch  15 Batch  102/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9279, Loss: 0.0410
# Epoch  15 Batch  153/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9318, Loss: 0.0533
# Epoch  15 Batch  204/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9343, Loss: 0.0657
# Epoch  15 Batch  255/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9343, Loss: 0.0506
# Epoch  15 Batch  306/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9254, Loss: 0.0561
# Epoch  15 Batch  357/1077 - Train Accuracy: 0.9308, Validation Accuracy: 0.9389, Loss: 0.0472
# Epoch  15 Batch  408/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9304, Loss: 0.0529
# Epoch  15 Batch  459/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9279, Loss: 0.0485
# Epoch  15 Batch  510/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9254, Loss: 0.0511
# Epoch  15 Batch  561/1077 - Train Accuracy: 0.9509, Validation Accuracy: 0.9261, Loss: 0.0409
# Epoch  15 Batch  612/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9421, Loss: 0.0412
# Epoch  15 Batch  663/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9300, Loss: 0.0382
# Epoch  15 Batch  714/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9233, Loss: 0.0363
# Epoch  15 Batch  765/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9421, Loss: 0.0493
# Epoch  15 Batch  816/1077 - Train Accuracy: 0.9655, Validation Accuracy: 0.9343, Loss: 0.0511
# Epoch  15 Batch  867/1077 - Train Accuracy: 0.8902, Validation Accuracy: 0.9286, Loss: 0.0836
# Epoch  15 Batch  918/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9421, Loss: 0.0453
# Epoch  15 Batch  969/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9386, Loss: 0.0540
# Epoch  15 Batch 1020/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9325, Loss: 0.0428
# Epoch  15 Batch 1071/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9375, Loss: 0.0438
# Epoch  16 Batch   51/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9407, Loss: 0.0437
# Epoch  16 Batch  102/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9361, Loss: 0.0356
# Epoch  16 Batch  153/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9261, Loss: 0.0497
# Epoch  16 Batch  204/1077 - Train Accuracy: 0.9164, Validation Accuracy: 0.9357, Loss: 0.0646
# Epoch  16 Batch  255/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9482, Loss: 0.0501
# Epoch  16 Batch  306/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9357, Loss: 0.0519
# Epoch  16 Batch  357/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9261, Loss: 0.0420
# Epoch  16 Batch  408/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9453, Loss: 0.0438
# Epoch  16 Batch  459/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9272, Loss: 0.0428
# Epoch  16 Batch  510/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9389, Loss: 0.0544
# Epoch  16 Batch  561/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9414, Loss: 0.0365
# Epoch  16 Batch  612/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9489, Loss: 0.0434
# Epoch  16 Batch  663/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9382, Loss: 0.0381
# Epoch  16 Batch  714/1077 - Train Accuracy: 0.9647, Validation Accuracy: 0.9432, Loss: 0.0423
# Epoch  16 Batch  765/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9453, Loss: 0.0462
# Epoch  16 Batch  816/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.9545, Loss: 0.0425
# Epoch  16 Batch  867/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.9318, Loss: 0.0866
# Epoch  16 Batch  918/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9538, Loss: 0.0443
# Epoch  16 Batch  969/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9506, Loss: 0.0511
# Epoch  16 Batch 1020/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9460, Loss: 0.0361
# Epoch  16 Batch 1071/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9446, Loss: 0.0377
# Epoch  17 Batch   51/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9609, Loss: 0.0402
# Epoch  17 Batch  102/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9460, Loss: 0.0385
# Epoch  17 Batch  153/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9474, Loss: 0.0439
# Epoch  17 Batch  204/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9364, Loss: 0.0590
# Epoch  17 Batch  255/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9453, Loss: 0.0420
# Epoch  17 Batch  306/1077 - Train Accuracy: 0.9356, Validation Accuracy: 0.9414, Loss: 0.0540
# Epoch  17 Batch  357/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9418, Loss: 0.0414
# Epoch  17 Batch  408/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9460, Loss: 0.0471
# Epoch  17 Batch  459/1077 - Train Accuracy: 0.9554, Validation Accuracy: 0.9407, Loss: 0.0418
# Epoch  17 Batch  510/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9364, Loss: 0.0426
# Epoch  17 Batch  561/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9489, Loss: 0.0411
# Epoch  17 Batch  612/1077 - Train Accuracy: 0.9554, Validation Accuracy: 0.9432, Loss: 0.0347
# Epoch  17 Batch  663/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9396, Loss: 0.0404
# Epoch  17 Batch  714/1077 - Train Accuracy: 0.9736, Validation Accuracy: 0.9563, Loss: 0.0381
# Epoch  17 Batch  765/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9574, Loss: 0.0482
# Epoch  17 Batch  816/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.9482, Loss: 0.0383
# Epoch  17 Batch  867/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.9279, Loss: 0.0810
# Epoch  17 Batch  918/1077 - Train Accuracy: 0.9483, Validation Accuracy: 0.9474, Loss: 0.0378
# Epoch  17 Batch  969/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9528, Loss: 0.0467
# Epoch  17 Batch 1020/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9375, Loss: 0.0336
# Epoch  17 Batch 1071/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9361, Loss: 0.0351
# Epoch  18 Batch   51/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9602, Loss: 0.0379
# Epoch  18 Batch  102/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9574, Loss: 0.0340
# Epoch  18 Batch  153/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9432, Loss: 0.0422
# Epoch  18 Batch  204/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9467, Loss: 0.0582
# Epoch  18 Batch  255/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9485, Loss: 0.0387
# Epoch  18 Batch  306/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9521, Loss: 0.0534
# Epoch  18 Batch  357/1077 - Train Accuracy: 0.9446, Validation Accuracy: 0.9446, Loss: 0.0454
# Epoch  18 Batch  408/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9489, Loss: 0.0438
# Epoch  18 Batch  459/1077 - Train Accuracy: 0.9580, Validation Accuracy: 0.9517, Loss: 0.0411
# Epoch  18 Batch  510/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9432, Loss: 0.0397
# Epoch  18 Batch  561/1077 - Train Accuracy: 0.9639, Validation Accuracy: 0.9556, Loss: 0.0339
# Epoch  18 Batch  612/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9542, Loss: 0.0380
# Epoch  18 Batch  663/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9467, Loss: 0.0420
# Epoch  18 Batch  714/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9620, Loss: 0.0396
# Epoch  18 Batch  765/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9517, Loss: 0.0487
# Epoch  18 Batch  816/1077 - Train Accuracy: 0.9671, Validation Accuracy: 0.9506, Loss: 0.0395
# Epoch  18 Batch  867/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9400, Loss: 0.0827
# Epoch  18 Batch  918/1077 - Train Accuracy: 0.9546, Validation Accuracy: 0.9503, Loss: 0.0385
# Epoch  18 Batch  969/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9560, Loss: 0.0503
# Epoch  18 Batch 1020/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9343, Loss: 0.0347
# Epoch  18 Batch 1071/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9567, Loss: 0.0326
# Epoch  19 Batch   51/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9492, Loss: 0.0324
# Epoch  19 Batch  102/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9570, Loss: 0.0340
# Epoch  19 Batch  153/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9503, Loss: 0.0448
# Epoch  19 Batch  204/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9336, Loss: 0.0541
# Epoch  19 Batch  255/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9535, Loss: 0.0349
# Epoch  19 Batch  306/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9577, Loss: 0.0431
# Epoch  19 Batch  357/1077 - Train Accuracy: 0.9438, Validation Accuracy: 0.9524, Loss: 0.0406
# Epoch  19 Batch  408/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9588, Loss: 0.0467
# Epoch  19 Batch  459/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9521, Loss: 0.0400
# Epoch  19 Batch  510/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9563, Loss: 0.0424
# Epoch  19 Batch  561/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9485, Loss: 0.0382
# Epoch  19 Batch  612/1077 - Train Accuracy: 0.9528, Validation Accuracy: 0.9666, Loss: 0.0400
# Epoch  19 Batch  663/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9453, Loss: 0.0327
# Epoch  19 Batch  714/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9478, Loss: 0.0356
# Epoch  19 Batch  765/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9517, Loss: 0.0456
# Epoch  19 Batch  816/1077 - Train Accuracy: 0.9659, Validation Accuracy: 0.9375, Loss: 0.0388
# Epoch  19 Batch  867/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.9503, Loss: 0.0802
# Epoch  19 Batch  918/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9616, Loss: 0.0372
# Epoch  19 Batch  969/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9478, Loss: 0.0468
# Epoch  19 Batch 1020/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9631, Loss: 0.0307
# Epoch  19 Batch 1071/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9471, Loss: 0.0351
# Model Trained and Saved

# %%
# Print the loss and test/validation accuracies.

# Increase size of the subplots.
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 24 
fig_size[1] = 16
plt.rcParams["figure.figsize"] = fig_size

# ----- START ----- #
print("# Batches: {}".format(len(batches)))
loss_plot = plt.subplot(211)
loss_plot.set_title('Loss')
loss_plot.plot(batches, losses, 'g')
loss_plot.set_xlim([batches[0], batches[-1]])

acc_plot = plt.subplot(212)
acc_plot.set_title('Accuracy')
acc_plot.plot(batches, train_accs, 'r', label='Training Accuracy')
acc_plot.plot(batches, valid_accs, 'x', label='Validation Accuracy')
acc_plot.set_ylim([0, 1.0])
acc_plot.set_xlim([batches[0], batches[-1]])
acc_plot.legend(loc=4)

plt.tight_layout()
plt.show()
# ----- END ----- #
# Out:
# # Batches: 420

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    unk_id = vocab_to_int['<UNK>']
    return [vocab_to_int.get(w, unk_id) for w in sentence.lower().split(' ')]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [147, 5, 133, 98, 60, 201, 54]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [175, 161, 167, 253, 28, 225, 163, 205, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
